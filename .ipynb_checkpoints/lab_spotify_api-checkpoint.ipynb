# %%
#!conda install -c conda-forge spotipy -y

# %%
import sys
from config import *

# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials 
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=Client_ID,
                                                           client_secret=Client_Secret))

# %%
import pandas as pd
import numpy as np

# %%
sp._session.timeout = 10

# %%
# We define the function to get the song id, based on the title and artist:
import pandas as pd
def search_song(title:str, artist:str=None, lim: int = 5):
    if artist:
        query = f"track:{title} artist:{artist}"
    else:
        query = f"track:{title}"
    try:
        results = sp.search(q=query)
        tracks = results['tracks']['items']
        if not tracks:
            print("Song", title, "from", artist, "not found!")
            return pd.DataFrame()
        
        # Extract relevant information from each track
        records = []
        for track in tracks[:lim]:
            record = {
                'title': track['name'],
                'artist': ', '.join([artist['name'] for artist in track['artists']]),
                'id': track['id']
            }
            records.append(record)
            
        # Create DataFrame from the list of records
        df = pd.DataFrame(records)
        return df
    
    except Exception as e:
        print(f"Error: {e}")
        return pd.DataFrame()

# %%
#testing the search song function
search_song("imagine",'john lennon', 1)
# Out:
#                        title       artist                      id
# 0  Imagine - Remastered 2010  John Lennon  7pKfPomDEeI4TPT6EOYjn9

# %%
# loading the dataframe with the hot 100 songs
hot_100= pd.read_csv('../../../Day_1/Morning/lab-web-scraping-single-page/hot_100.csv')

# %%
for index, row in hot_100.iterrows():
    result_df=search_song(row['title'], row['artist'], 1)
    if not result_df.empty:
        hot_100.at[index, 'id'] = result_df['id'].values[0]
    else:
        hot_100.at[index, 'id'] = ""
# Out:
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Song I Remember Everything from Zach Bryan Featuring Kacey Musgraves not found!
# Song Rich Baby Daddy from Drake Featuring Sexyy Red & SZA not found!
# Song Everybody from Nicki Minaj Featuring Lil Uzi Vert not found!
# Song First Person Shooter from Drake Featuring J. Cole not found!
# Song Surround Sound from JID Featuring 21 Savage & Baby Tate not found!
# Song IDGAF from Drake Featuring Yeat not found!
# Song Hey Driver from Zach Bryan Featuring The War And Treaty not found!
# Song Different 'Round Here from Riley Green Featuring Luke Combs not found!
# Song Man Made A Bar from Morgan Wallen Featuring Eric Church not found!
# Song We Don't Fight Anymore from Carly Pearce Featuring Chris Stapleton not found!
# Song Que Onda from Calle 24 x Chino Pacas x Fuerza Regida not found!
# Song FE!N from Travis Scott Featuring Playboi Carti not found!
# Song Can't Have Mine from Dylan Scott not found!
# Song Needle from Nicki Minaj Featuring Drake not found!
# Song Slime You Out from Drake Featuring SZA not found!
# Song Turks & Caicos from Rod Wave Featuring 21 Savage not found!

# %%
display(hot_100)
# Out:
#                                   artist                        title  \
# 0                            Jack Harlow                  Lovin On Me
# 1                           Taylor Swift                 Cruel Summer
# 2                             Tate McRae                       Greedy
# 3                               Doja Cat           Paint The Town Red
# 4   Zach Bryan Featuring Kacey Musgraves        I Remember Everything
# ..                                   ...                          ...
# 95                            Zach Bryan                   Tourniquet
# 96                              Junior H                      Y Lloro
# 97                   Sophie Ellis-Bextor     Murder On The Dancefloor
# 98                               Karol G                     Amargura
# 99                         Lainey Wilson  Wildflowers And Wild Horses
#
#                         id
# 0
# 1   1BxfuPKGuaTgP7aM0Bbdwr
# 2   3rUGC1vUpkDG9CZFHMur1t
# 3   2IGMVunIBsBLtEQyoI1Mu7
# 4
# ..                     ...
# 95  3EvZ03hGAFwGZ2Ebcu86YH
# 96  6RcAHyC5sAUIbPTkhOQwd8
# 97  4tKGFmENO69tZR9ahgZu48
# 98  505v13epFXodT9fVAJ6h8k
# 99  6d3QUBsiAw3aZI6F2mMhzk
#
# [100 rows x 3 columns]

# %%
hot_100=hot_100[hot_100["id"]!=""]
display(hot_100.head())
hot_100.shape
# Out:
#          artist               title                      id
# 1  Taylor Swift        Cruel Summer  1BxfuPKGuaTgP7aM0Bbdwr
# 2    Tate McRae              Greedy  3rUGC1vUpkDG9CZFHMur1t
# 3      Doja Cat  Paint The Town Red  2IGMVunIBsBLtEQyoI1Mu7
# 5           SZA              Snooze  4iZ4pt7kvcaH6Yo8UoZ4s2
# 6          Tyla               Water  5aIVCx5tnk0ntmdiinnYvw
# (83, 3)

# %%
# I load the not_hot songs df
not_hot= pd.read_csv('../../../Day_1/Afternoon/lab-not-hot-songs/not_hot_songs.csv')

# %%
# Show the shape and the head:
display(not_hot.shape)
not_hot.head()
# Out:
# (3000, 2)
#                    artist                              title
# 0            glenn miller    the little man who wasn't there
# 1                 misfits                    american psycho
# 2           elliott smith       somebody that i used to know
# 3        june carter cash                     juke box blues
# 4  emerson, lake & palmer  karn evil 9 1st impression, pt. 1

# %%
# I apply the search_song to create an extra column into the not_hot df and obtain the id.
# we print those songs for which no id was found.
for index, row in not_hot.iterrows():
    result_df=search_song(row['title'], row['artist'], 1)
    if not result_df.empty:
        not_hot.at[index, 'id'] = result_df['id'].values[0]
    else:
        not_hot.at[index, 'id'] = ""
# Out:
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# Song i'll drown in my tears from johnny winter not found!
# Song can't cash my checks from jamey johnson not found!
# Song it'll be her from waylon jennings not found!
# Song don't need no horse from little walter not found!
# Song it's great to be alive from johnny mercer not found!
# Song you're nobody til somebody loves you from sam cooke not found!
# Song i'll thank you all my life from jean shepard not found!
# Song don't change from simplified not found!
# Song let's fall in love from nancy sinatra not found!
# Song death to everyone from bonnie "prince" billy not found!
# Song i'll never fall in love again from mary chapin carpenter not found!
# Song let's get together (one last time) from tammy wynette not found!
# Song sympathy for the devil from jane's addiction not found!
# Song i'm broke from black joe lewis & the honeybears not found!
# Song that's us/wild combination from arthur russell not found!
# Song livin' easy (feat. stick figure) from kbong not found!
# Song you'll never walk alone from the flamingos not found!
# Song منك بخاف from rania not found!
# Error: 'NoneType' object is not subscriptable
# Song no more disguise (feat. lou lou ghelichkhani) from thievery corporation not found!
# Song that's alright from muddy waters not found!
# Song why can't i love you from hiroshima not found!
# Song ron's place from brad mehldau not found!
# Song i've been there from irma thomas not found!
# Song freek'n you from jodeci not found!
# Song i've got a quarter in my pocket from gary allan not found!
# Song warm brew from leaf beach not found!
# Song can't you just see me from aretha franklin not found!
# Song it's too late from marvin sease not found!
# Song i'm leaving now from johnny cash not found!
# Song it's my job to keep punk rock elite from nofx not found!
# Song it's the talk of the town from dean martin not found!
# Song that's as close as i'll get to loving you from aaron tippin not found!
# Song i'll sleep when i'm dead from warren zevon not found!
# Song i'm through with love from chuck berry not found!
# Song there's you from cody johnson not found!
# Song today's lonely fool from tracy lawrence not found!
# Song i'd love you all over again from alan jackson not found!
# Song don't walk away from no justice not found!
# Song out from under from ali campbell not found!
# Song you're not the one (i was looking for) from blue öyster cult not found!
# Song it's all in the game from ricky nelson not found!
# Song trouble ain't far behind from gary moore not found!
# Song herbalist from mungo's hi fi not found!
# Song i'm free from merle haggard not found!
# Song how's the radio know from aaron tippin not found!
# Song there's no one else from robben ford not found!
# Song towering fool from gov't mule not found!
# Song it's probably me from sting not found!
# Song don't ask me why from elvis presley not found!
# Song he's a tramp from melody gardot not found!
# Song this what i call her from lil wayne not found!
# Song i've lived a lot in my time from jim reeves not found!
# Song you're sixteen from johnny burnette not found!
# Song you'll always be the one i love from dean martin not found!
# Song i've got you under my skin from shirley bassey not found!
# Song undercover lover (feat. gonzo) from tribal seeds not found!
# Song like a hurricane from the jeff healey band not found!
# Song it's a blue world from ella fitzgerald not found!
# Song boss's daughter from pop evil not found!
# Song don't forget me (when i'm gone) from glass tiger not found!
# Song i've got a crush on you from steve tyrell not found!
# Song don't you know from one drop not found!
# Song i'll have to make some changes from marty robbins not found!
# Song you're my favorite song from demi lovato not found!
# Song i'm not awake yet from rory gallagher not found!
# Song why'd you lie? from colin james not found!
# Song old before my time from the allman brothers band not found!
# Song grey cell green from ned's atomic dustbin not found!
# Song play it cool from brand nubian not found!
# Song i'll walk alone from dinah shore not found!
# Song you're beautiful from shane & shane not found!
# Song can't say from travis scott not found!
# Song cain't no grave hold my body down from sister rosetta tharpe not found!
# Song nothing's news from clint black not found!
# Song we're all in love from black rebel motorcycle club not found!
# Song it's alright from slim smith not found!
# Song one more time from kxng crooked not found!
# Song i'll always love you from tito nieves not found!
# Song didn't we from astrud gilberto not found!
# Song pure from blue six not found!
# Song he's a tryer from chris ledoux not found!
# Song on the run from royce da 5'9" not found!
# Song around the town from gino washington not found!
# Song i'm shooting high from nat king cole not found!
# Song we've got a score to settle from the dear hunter not found!
# Song don't ever leave me from paul anka not found!
# Song you've given me something from orleans not found!
# Song hiding my heart from adele not found!
# Song don't forget from the platters not found!
# Song that's the way love goes from johnny rodriguez not found!
# Song i'll never be free from jean shepard not found!
# Song i've got the world on a string from diana krall not found!
# Song moonlight bay from bing crosby not found!
# Song that's all right mama from canned heat not found!
# Song can't help yourself from the blackwater fever not found!
# Song i'm loving nothing from the impressions not found!
# Song i'd still be there from johnny cash not found!
# Song packt like sardines in a crushed tin box from radiohead not found!
# Song we're here to love from ronnie milsap not found!
# Song pegasus from the allman brothers band not found!
# Song it's not over (if i'm not over you) from reba mcentire not found!
# Song tired eyes from neil young not found!
# Song i've grown accustomed to her face from dean martin not found!
# Song that's how i got to memphis from tom t. hall not found!
# Song ruff tuff from can't hang not found!
# Song don't wanna lose you from gloria estefan not found!
# Song does it really make a difference (feat. mavis staples) from galactic not found!
# Song i'm gonna love you too from buddy holly not found!
# Song i'm old fashioned from andy williams not found!
# Song time (feat. corey harris & ranking joe) from easy star all-stars not found!
# Song (i'm always touched by your) presence dear from blondie not found!
# Song i'll never break your heart from backstreet boys not found!
# Song take it as you want (parto opos thes) from terror x crew not found!
# Song that's my home from louis prima not found!
# Song don't walk away from danger danger not found!
# Song i've got time from soja not found!
# Song that's why i pray from big & rich not found!
# Song i'm not that nigga! from bone thugs-n-harmony not found!
# Song he's just an old love turned memory from tammy wynette not found!
# Song i'll be your jonny on the spot from ween not found!
# Song don't you believe her from ray price not found!
# Song i'll be long gone from boz scaggs not found!
# Song i'm a rocker from bruce springsteen not found!
# Song can't sleep at night from susan tedeschi not found!
# Song yesterday's mistakes from oi va voi not found!
# Song two rights from the allman brothers band not found!
# Song love all the hurt away from george benson not found!
# Song you're my witness from clay walker not found!
# Song camilo from chadwick stokes not found!
# Song what's love (feat. akon) from shaggy not found!
# Song can't use me from john holt not found!
# Song baby's got a hold on me from nitty gritty dirt band not found!
# Song hip hop kid from afu-ra not found!
# Song let's seize the time from jimmy cliff not found!
# Song firelight (feat. lou lou ghelichkhani) from thievery corporation not found!
# Song you'll never be the same from graham nash not found!
# Song don't let your sweet love die from ricky skaggs not found!
# Song won't go home without you from maroon 5 not found!
# Song i'm gonna be free from the ethiopians not found!
# Song gideon's bible from john cale not found!
# Song you've changed from dexter gordon not found!
# Song that's gonna leave a memory from easton corbin not found!
# Song (we're gonna) rock around the clock from bill haley & his comets not found!
# Song you'll lose a good thing from aretha franklin not found!
# Song it's gotta be you from lesley gore not found!
# Song i'll be easy to find from johnny mathis not found!
# Song it's not over (if i'm not over you) from mark chesnutt not found!
# Song keep your worries from guru's jazzmatazz not found!
# Song devil's dance from cortex not found!
# Song the sign of fire from the fixx not found!
# Song love help me from deep purple not found!
# Song gangsta's fairytale 2 from ice cube not found!
# Song can't stop me now from ted nugent not found!
# Song there's a limit from stonewall jackson not found!
# Song dirt road dollars from dirt rock empire not found!
# Song i'll play for you from seals and crofts not found!
# Song we've only just begun from andy williams not found!
# Song everything (feat. bajka) from radio citizen not found!
# Song don't your mem'ry ever sleep at night from ronnie milsap not found!
# Song just for you from can't hang not found!
# Song what's true from ziggy marley & the melody makers not found!
# Song gilbert's grove from desmond cheese not found!
# Song gin and juice (feat. dat nigga daz) from snoop dogg not found!
# Song it's de-lovely from oscar peterson not found!
# Song it's a lovely day today from ella fitzgerald not found!
# Song jimmy's bonus beat from jungle brothers not found!
# Song goofy's concern from butthole surfers not found!
# Song let's fall in love from betty carter not found!
# Song i'm not strong enough to say no from blackhawk not found!
# Song can't help falling in love with you from harry connick, jr. not found!
# Song (i'd be) a legend in my time from don gibson not found!
# Song ain't got nothin' from supreme beings of leisure not found!
# Song frankie's gun! from the felice brothers not found!
# Song i'm alone in the wilderness from culture not found!
# Song tell me the story from the grace thrillers not found!
# Song ain't life grand from widespread panic not found!
# Song i'll always be loving you from george strait not found!

# %%
# We filter out the records with empty id
not_hot = not_hot[not_hot['id']!= ""]
display(not_hot.head(10))
not_hot.shape
# Out:
#                      artist                              title  \
# 1                   misfits                    american psycho
# 2             elliott smith       somebody that i used to know
# 3          june carter cash                     juke box blues
# 4    emerson, lake & palmer  karn evil 9 1st impression, pt. 1
# 5   queens of the stone age                  another love song
# 6                     adema                           immortal
# 7              the supremes          stop! in the name of love
# 8   the notting hillbillies                         bewildered
# 9            sticky fingers                              hyper
# 10              diana krall                         walk on by
#
#                         id
# 1   77v5yDwMLiJlIsHNJQxXrY
# 2   4xfAVJL8R7mVYbDk8a9xOY
# 3   5x46pk7OZUv1WWiP6iEdMy
# 4   6WfjV745TiUcD8KdUKp241
# 5   5HjEC3NlSzKsVKmqnhXrum
# 6   4pawqkNZXTbqrYAd0I5Wtb
# 7   52FlwUMMDnTK8TGkCag9Jd
# 8   3OhkFJSKPlrqjozVsBSami
# 9   2VkhnzJ1D0ipwbFbggo3Ry
# 10  4jZRI1v2LLaDTshDW9qruu
# (2821, 3)

# %%
# We define the function to retrieve the audio features for the different chunks we have created before
import pandas as pd
import time

def get_audio_features_for_chunks(sp, list_of_song_ids, chunk_size=50, sleep_time=20):

    # Split the list_of_song_ids into chunks of size chunk_size
    song_id_chunks = [list_of_song_ids[i:i + chunk_size] for i in range(0, len(list_of_song_ids), chunk_size)]

    # Create an empty DataFrame to store the audio features
    df_audio_features = pd.DataFrame()

    # Iterate through each chunk
    for chunk in song_id_chunks:
        print("Collecting audio features for chunk...")
        time.sleep(sleep_time) 
        my_dict = sp.audio_features(chunk)

        # Check if my_dict is not None and contains elements before creating a DataFrame
        if my_dict and isinstance(my_dict, list) and len(my_dict) > 0:
            # Create a new dictionary with a more structured format
            my_dict_new = {key: [item[key] for item in my_dict] for key in my_dict[0]}

            # Create a DataFrame from the audio features and append it to df_audio_features
            df_chunk = pd.DataFrame(my_dict_new)
            df_audio_features = pd.concat([df_audio_features, df_chunk], ignore_index=True)

    return df_audio_features

# %%
# get list with all the ids from hot_song df
hot_song_id_list = hot_100["id"].values.tolist()
display(hot_song_id_list)
# Out:
# ['1BxfuPKGuaTgP7aM0Bbdwr',
#  '3rUGC1vUpkDG9CZFHMur1t',
#  '2IGMVunIBsBLtEQyoI1Mu7',
#  '4iZ4pt7kvcaH6Yo8UoZ4s2',
#  '5aIVCx5tnk0ntmdiinnYvw',
#  '7K3BhSpAxZBznislvUMVtn',
#  '1Lo0QY9cvc8sUB2vnIOxDT',
#  '7dJYggqjKo71KI9sLzqCs8',
#  '0PAcdVzhPO4gq1Iym9ESnK',
#  '6usohdchdzW9oML7VC4Uhk',
#  '1Iq8oo9XkmmvCQiGOfORiz',
#  '0cVyQfDyRnMJ0V3rjjdlU3',
#  '7DSAEUvxU8FajXtRloy8M0',
#  '1a73gcEg6h6Re6hHXoVltJ',
#  '7MSWxMumjz6lHj7oRApNbg',
#  '0mflMxspEfB0VbI1kyLiAv',
#  '6wf7Yu7cxBSPrRlWeSeK0Q',
#  '1kuGVB7EU95pJObxwvfwKS',
#  '07on0OB2cdPt79IFsgdRUy',
#  '1vYXt7VSjH9JIM5oRRo7vA',
#  '4rXLjWdF2ZZpXCVTfWcshS',
#  '5ya0TmUQw2wHMkq36rPsnd',
#  '4OMJGnvZfDvsePyCwRGO7X',
#  '30LZU3ReFIndjHLfaahreM',
#  '41WQUSINanQHfhfKpFDsms',
#  '1Qrg8KqiBpW07V7PNxwwwL',
#  '0J1YRLYhTG1MBosjidD7OI',
#  '2gT2iF1YK5r54A2PDEXVv8',
#  '0R6NfOiLzLj4O5VbYSJAjf',
#  '7DswEZZthZ6piQpL25qGAM',
#  '103u49mLoJUge83B1CnLxI',
#  '3vkCueOmm7xQDoJ17W1Pm3',
#  '7hZTywPKMdVjJzwdWu11BK',
#  '0HD8mbiPjp3o94X3EaZp0o',
#  '6wsqVwoiVH2kde4k4KKAFU',
#  '2kE2HFBFkJ0VMw3igxYohz',
#  '5mjYQaktjmjcMKcUIcqz4s',
#  '4MjDJD8cW7iVeWInc2Bdyj',
#  '6UoKX6uLJwhsnyTp5k5StP',
#  '2gyxAWHebV7xPYVxqoi86f',
#  '6uTPdRrEDeH8Fyg5L5qmeU',
#  '22VHOlVYBqytsrAqV8yXBK',
#  '0eBFgRxyVSeuT4iyrbukdn',
#  '5Se32hEA9raeboZerywxka',
#  '6CvTEtGagmzQvkUzzyKR9k',
#  '4bARASJEokNacSYtEhoNBp',
#  '05WVKTdZhlIMX4qqMLuo0f',
#  '5XVdHRf4CAJ2Jm0uMIy5qY',
#  '2Zo1PcszsT9WQ0ANntJbID',
#  '6rjuKpPydT2SxN15TZpV7r',
#  '5RqSsdzTNPX1uzkmlHCFvK',
#  '2eGvz6O6tVnh9nKiitDEhZ',
#  '3CWq0pAKKTWb0K4yiglDc4',
#  '7rr3gguU3TcVnLZD9VzASE',
#  '56xHMIfQPoe0prrSi3BGhf',
#  '6fNCrsrdIcgVd2aZZ0nnz4',
#  '0O3U5iwTbiXCREMkvotJuN',
#  '5C8h9PY9oTneqJihbn10NB',
#  '7CyPwkp0oE8Ro9Dd5CUDjW',
#  '2KslE17cAJNHTsI2MI0jb2',
#  '1ZpPaBDswjV3VSUKqLDXPE',
#  '7iQXYTyuG13aoeHxGG28Nh',
#  '0OWhKvvsHptt6vnnNUSM9a',
#  '1OG7o5af3ILKrFkp7pvvb0',
#  '1nQaTUDJ7Rc4yOvZmg9Ozr',
#  '4M68xjcc42oxyphhzpOWXS',
#  '3IX0yuEVvDbnqUwMBB3ouC',
#  '2OWv3lRR8PtOVuHWzQNRs2',
#  '3eP13S8D5m2cweMEg3ZDed',
#  '78Du4CMFgnhdlG33gblkiP',
#  '4oEf84vBYVftf6KmZexhVo',
#  '5KD6AEm19QnMbfWpfoOHMl',
#  '4qmG24ebshLXtKu9HIShBP',
#  '54zcJnb3tp9c5OVKREZ1Is',
#  '51hyZpbJlIgZIaX3TtMxmu',
#  '1bHnRc60O1N0l3PbHjaKyK',
#  '5jfhLCSIFUO4ndzNRh4w4G',
#  '4kjI1gwQZRKNDkw1nI475M',
#  '3EvZ03hGAFwGZ2Ebcu86YH',
#  '6RcAHyC5sAUIbPTkhOQwd8',
#  '4tKGFmENO69tZR9ahgZu48',
#  '505v13epFXodT9fVAJ6h8k',
#  '6d3QUBsiAw3aZI6F2mMhzk']

# %%
# we get the audio features for the hot_songs df:
hot_songs_feat = get_audio_features_for_chunks(sp, hot_song_id_list, chunk_size=50, sleep_time=20)
# Out:
# Collecting audio features for chunk...
# Collecting audio features for chunk...

# %%
display(hot_songs_feat.shape)
hot_songs_feat.head()
# Out:
# (83, 18)
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.552   0.702    9    -5.707     1       0.1570        0.1170
# 1         0.750   0.733    6    -3.180     0       0.0319        0.2560
# 2         0.868   0.538    5    -8.603     1       0.1740        0.2690
# 3         0.559   0.551    5    -7.231     1       0.1320        0.1410
# 4         0.673   0.722    3    -3.495     0       0.0755        0.0856
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000021    0.1050    0.564  169.994  audio_features
# 1          0.000000    0.1140    0.844  111.018  audio_features
# 2          0.000003    0.0901    0.732   99.968  audio_features
# 3          0.000000    0.1100    0.392  143.008  audio_features
# 4          0.000000    0.1370    0.519  117.187  audio_features
#
#                        id                                   uri  \
# 0  1BxfuPKGuaTgP7aM0Bbdwr  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 1  3rUGC1vUpkDG9CZFHMur1t  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 2  2IGMVunIBsBLtEQyoI1Mu7  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 3  4iZ4pt7kvcaH6Yo8UoZ4s2  spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 4  5aIVCx5tnk0ntmdiinnYvw  spotify:track:5aIVCx5tnk0ntmdiinnYvw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 1  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 2  https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 3  https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 4  https://api.spotify.com/v1/tracks/5aIVCx5tnk0n...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 1  https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 2  https://api.spotify.com/v1/audio-analysis/2IGM...       231750
# 3  https://api.spotify.com/v1/audio-analysis/4iZ4...       201800
# 4  https://api.spotify.com/v1/audio-analysis/5aIV...       200256
#
#    time_signature
# 0               4
# 1               1
# 2               4
# 3               4
# 4               4

# %%
# we get the list of song id for the not_hot df:
not_hot_song_id_list = not_hot["id"].tolist()
not_hot_song_id_list
# Out:
# ['77v5yDwMLiJlIsHNJQxXrY',
#  '4xfAVJL8R7mVYbDk8a9xOY',
#  '5x46pk7OZUv1WWiP6iEdMy',
#  '6WfjV745TiUcD8KdUKp241',
#  '5HjEC3NlSzKsVKmqnhXrum',
#  '4pawqkNZXTbqrYAd0I5Wtb',
#  '52FlwUMMDnTK8TGkCag9Jd',
#  '3OhkFJSKPlrqjozVsBSami',
#  '2VkhnzJ1D0ipwbFbggo3Ry',
#  '4jZRI1v2LLaDTshDW9qruu',
#  '7vrLphPq4yjaX7jiDdd2Nc',
#  '6WmIyn2fx1PKQ0XDpYj4VR',
#  '5n7JHKyKIJXMXXv10f1AYk',
#  '7noRPNdNTDJSHIvAl5xQL2',
#  '67Fxvtgc3MXl2x4ryyFpw7',
#  '4IMN8BxmU5Gbpz68Xw9lFw',
#  '4c4LylLvTh91IhwQgSXPRc',
#  '43uplr4bhcs8FJIU5KBzB1',
#  '0Y8og0cMFAwf12eW64WoYE',
#  '1axzRYUUASTfN4OOtrjfQd',
#  '63U9mJpffoQILdkb1VWDK8',
#  '3gfwt1C4Jt7qhjpILxYUtp',
#  '2qAjQGlYOllN6tll1pgmLm',
#  '531muHgVZoRgYXK5Qb59Pz',
#  '7GQZYw55Juuq3tntjZJzZt',
#  '3zyj0RajXg2w2Bnn773mnW',
#  '0vMI3AJPQMjytAu8XMWr65',
#  '3TMxeYDa7yOKAxMUaCQWv4',
#  '0Xwfq9T1CruynQcHKY1hs4',
#  '6JkgdaqqIcisr9QNzseLCl',
#  '561t8Mil2myu0i8N2Qwij4',
#  '6r9tjMWLv8fNdZKKTnqCEr',
#  '5FZtl28q6FXkuDeAWxHzjx',
#  '7wCaeyWeyBzYbO5bxinQlM',
#  '6avRZyfcRndnnbyPtdZQjq',
#  '0Dit4xsY3yFY73b19VxsYE',
#  '7l7qkt9cvhBN9LtZzF8pdT',
#  '2wNK1PjIS9NbBIchakaL7k',
#  '0R5BQ3uQkPKITB7rDgNUhh',
#  '7moS0kYQ3AEQF79F1TW2br',
#  '3Woz4yXgXOSTs6Yc0Oh2Es',
#  '6VNZ2wD3ylpNKHZcz5RluU',
#  '5HiI5koKreGVsXAB5F0uuw',
#  '4jHlDYHJOjDf8hSVJC6hkW',
#  '1ZEoYuekZQo62DLFtPVdqT',
#  '5ZeMGAJVrndrE0pVLo593J',
#  '0gKiONJeEtwb3hps4sUgyn',
#  '1IdTBf0QfIvl4giLRuNOk0',
#  '3hfBEQdxCDfrCOpEqo5Dpt',
#  '4NfNr2aOxfZkkDHue5gjKf',
#  '1JlZVLefhkfycX8WfJdlSR',
#  '0UGsSjbp8vhm8QfNOIdmMy',
#  '1NCWCb7cJN99U49oo1Fibg',
#  '0HQE2SbrXTX849UcgfXLad',
#  '4OPFX9TRHlEz1M5JGCvoiL',
#  '6a0zu7tOqPUHQfoP7YJ9nS',
#  '2P7dqEsGAvdVBCWeycm0vI',
#  '5rtGkBfghA7kPeg8o1PKw3',
#  '6CAkmqFlO5S3o0QDUuzcYr',
#  '33WjZmABjWk4zrerZiFLJ7',
#  '4OHVCeQYPncEwZOtNAJZZx',
#  '4M0u1UX3jKB7MNoTU6nZwg',
#  '5p93xQCbw0ZZxCML17PErR',
#  '1BQ7NbAotfutwilc1ErwYz',
#  '3w3EjnBINTADx3JHF3aiiy',
#  '1g4ziqH1kWahITvZg8ppUO',
#  '60voQIiwEp0n6H7Qhu6AwH',
#  '1niBlhuYWv5D52E1z8PrmI',
#  '71vyz1pfzmj1MQvJYOsPlb',
#  '4SHDceuWcvcq8eAze9zfQV',
#  '4gZqRlaWMKcjUFh1Uss8fI',
#  '0Fpzme3KEtRUYBz3EXbKml',
#  '4UtDrwAkSbrZgAUQSWKcti',
#  '5WTBrgJphk7N7MLcEmIANz',
#  '1fIeb00T7SCnsDMDvO5aIU',
#  '1dohIM3mw8wUL3YoYtlpJY',
#  '1NT5IEwmAcJARJWLWgSZXn',
#  '78MAFESapdJfHRXMzXfWjy',
#  '2mBI035RCSAHuxrdPK3PFi',
#  '5WR8MntC0zFs2jprgXXoD4',
#  '4lZjHEJXzKCCTVPtgYcypv',
#  '0GUH8i0exq2zaPWK4uEbg9',
#  '6zXIh2UYtB5b05QweNU9vO',
#  '3pPe5vc5aYV2cdUt11H54h',
#  '3OHdhLUobIIKskQHLJAaqe',
#  '2VGkf2IJXOSWouDhatlH3i',
#  '36Xf9sOj6JQnyBxKOQdAaF',
#  '4olPjhmLorTREwFO8YvHDk',
#  '06EnrkMo8s615M1rq9R0Nq',
#  '3T8Ye4NB0MQhcEcxzMdAuH',
#  '5hYr8yRbQLFE20oS7Mi3T2',
#  '4krdEDkfjBcyCxhi01r0Y6',
#  '0FurVQ0EokPigbJnjAJqX8',
#  '6joOV9D7y7TzWQprwrInUh',
#  '5L3Xsu9mgIhcTn86T5Nui0',
#  '0YkPyp7yX0O4fsg8ssBfpL',
#  '6dKntZwVJx0QLX6IM19gC7',
#  '48G6ACO6Awe7oZwvOKPVFC',
#  '7Cw9qRzAA9RMH4DxMkg6pr',
#  '1XXC4wrqwiNQZTrGvnbACG',
#  '35ynRVAgEtlqr82u5Mvlct',
#  '4ZRCedGgRihP3QkJuqDMOW',
#  '7JOyyggmgb5b3PjjUDNqYK',
#  '0Auq7v8eMbFXMi6ZaMCb09',
#  '5IfZsdLhf0g3q1LHOLWMKt',
#  '1pOw0A9OZ8VqQyuhGGBf3h',
#  '1705rRR3YgJWDNktkXE1qW',
#  '2khc6kEG4eBvYN1GvR6R97',
#  '1xYpVRspgaLxdJLOTQkTjg',
#  '6j6NF0hzixG0yHdWM0OEZg',
#  '3t9m9ddMxd3ff1Z9TLbGNA',
#  '0gsFtv4YvS6DQieNmc9Rc3',
#  '2Pm0K7SlmyQWfj4A7qFWc0',
#  '3c95UZIEy9cPgLBK4yKx78',
#  '33BrbTNaKetenya8gALcvK',
#  '4w4RaMGPl2qnjSdPlp1KAE',
#  '5azJ5CcX8EnNCRFog5G24Z',
#  '22HvxbTL45rqDZPNuMRkqg',
#  '19wyEOwk4PTvfhBxSoZ34a',
#  '4IbtKnLEvJZRnLhaVT2Yic',
#  '5WI2ltQIdwgzf1SNE76JyR',
#  '5a4MgIUSf9K8wXLSm6xPEx',
#  '1aSGE7H6pkelrCmdzMquEg',
#  '49biLp7sPTHLW6sQib5F0V',
#  '4ukeI7Wn6W02spgtwzBJt2',
#  '46xkXPGjR9Ig9BcaTUNus3',
#  '2S07mMXPl3teviPxwaHvPl',
#  '2jK9viQ42StKvURUlXbGqy',
#  '04BQXS1HwzNpfZ2Wvw2RIy',
#  '4Kkc9FUzcD4kAEM0DjbuUz',
#  '65vdMBskhx3akkG9vQlSH1',
#  '6fBy4h0spon7gkmZroCRmR',
#  '286mFeYjBJ9fkioaIzaxoN',
#  '5xsxWJdLyrLWQkkdtXp9sl',
#  '0xJ6Xr620TwVr6kqDSk5tn',
#  '7AFYQ5pNtS4I98PvFXkvid',
#  '3BYql2MM0Z6I2Z0fz0mc3X',
#  '6ug6ptKUZytbgvptMIM6vK',
#  '0wPi3JOWkhvk4vHYgf9yHG',
#  '5BBCf8WWFehDtOTJNaoR8P',
#  '7fvyyUAVBfErHVfmMCJraR',
#  '5sA5NQuETYhP1oxV36EJs9',
#  '0up9N5JtxdhoGUFSB9jGwa',
#  '5l8AvWEzLSiHajzkdQ6WYZ',
#  '6urBMNarztXhgZ93wItFTQ',
#  '6OTEWAR6832nNGILsXPALg',
#  '7FGX1mnDDyaQjm6I4r558o',
#  '59c7SUF845rKDIhvc67qHD',
#  '2wnsBaxrmkthIFAm6vqCuX',
#  '5wIXpK3BAW5geIlEmYf23n',
#  '4R9KztunyNTH13KtAqePLp',
#  '1lbU09e2SYXn5XluhI4djx',
#  '2bNxCVI4Fub8BAwr0CQDyd',
#  '0hwITjPhMWO19cP6SFFiU3',
#  '3SKJX0OsoSmrLghpTTgJdT',
#  '1OpzCsETUDNjY4noJRjAtP',
#  '3R4C2Jh2dtDs2DKZX3KpoQ',
#  '4kmGRW1BgoKendL6V7cz29',
#  '69uG8ZwlX20vA5fKIEu8J8',
#  '1cZ7NCXlGhz4RTGgLHZ7Ow',
#  '0TGzKjIXY3I5mZ6RpnSUGq',
#  '1XDKn16I6tc1PNpXf58y3t',
#  '4jqmLG3uxkNnpSKfEBiy2N',
#  '3cvPT7z9vGwot70G5Li3I5',
#  '38XUHcIwtJoiEXTyrC8pF9',
#  '3vm0aEj2SMGtncYdjU2DI7',
#  '2QjIEZJDtWVUx1X0dpjuJu',
#  '5L3Xsu9mgIhcTn86T5Nui0',
#  '2ni4ZSzsQoG74IUjYvyv8n',
#  '2RbJc1nH5N83pjZNnDMDZB',
#  '0lATXmstYwzQjOLgkzvnEc',
#  '2Knlcf82LF6hp6Bf0gldtN',
#  '1YtLghrMqyODC5183nwyZk',
#  '0Ot9ZoZNFa26smoiDLwauP',
#  '4rtnLe7BMoqxUj4Y8Wgqf6',
#  '65k1tfjXmOYbc3aLB3wliS',
#  '1w9LuGRGfZlE8AGDbSNOfT',
#  '3Ph7fws05DvPwpn5CQHTBy',
#  '57oVcyjYuoZfvxaTTJtTeG',
#  '4ByFEfZp8SNWQg8UuWLCmi',
#  '69jVqfSr1vOBjcsGJeijz1',
#  '63Od9t6xI8CiIkr7T3XZfr',
#  '6aPTenGczmhlZg1g14Mdff',
#  '1v77ybydQXVq6O9XnSDSdm',
#  '7rdUtXasA973gmrr2Xxh3E',
#  '5j3QqRGflS4o5jbsFSwKW1',
#  '3F3phA2ifyx8nRdnRazYVZ',
#  '4ZJPwET9Jrgpkqi4Vo3Yg8',
#  '68gliAoTqB2ykfVh1N18PS',
#  '78Cg7PEJ7zEvhZQUdiGktL',
#  '5RrJCusmR1J54b5ivqdWIu',
#  '7ss73yV5efYHgm9bAQ98JM',
#  '4pVA399XGov2hhrrxSJip2',
#  '4gNeiiz86Y5wekGwfIybXW',
#  '0Xd3LUIjRESt5rSAGzvAvA',
#  '3r3arRITkDDlm2RcH3E02k',
#  '3ENHpbTuY72FukZbwGP6bc',
#  '6FAI1jvFTpetUcmRxmnIqc',
#  '6uYRiyGQ3RLZwOKPnYgM14',
#  '4y65gEgkide7Phy9dgDRdq',
#  '6MLiQIWMaTaaOB04R1VC0k',
#  '6IlomAMOVnYbzWt6dMt5Cu',
#  '2w0bmfJun0gC8BOZxbaLAF',
#  '2JhIaeltCDCcp02K936tgx',
#  '5ZGaS6Q8WW21pyQWajBcXs',
#  '2nxSAQBvF6gDIwZmG6B9nO',
#  '7EumbJIbcVSyJSYKc4aVsT',
#  '3cl42VFcRop14wAduvSeaH',
#  '4rsxuPgzQGwaumPAVKW6qD',
#  '75dNOsoC6TLvSp4qkSBw4H',
#  '4OGyibX2nayDVCUfFN4u8x',
#  '52nVtrwHhGNThtA6RW0WMS',
#  '1J4JWWNq714qkRSEaLP4aM',
#  '1lL1jDnZTH60djVb6vKIQj',
#  '3kjPty1OcP5o2X1oLUlv4M',
#  '2ldalh6d2MrsAFaZG9H3P4',
#  '3DdOsUq1M9mJBFVR0xbSOx',
#  '5elDLvpi4MB1NT02PjbgtE',
#  '5kVOIixeGiFGY8cvWsiGgZ',
#  '71zA7wGhhDnpzhoPHpLth3',
#  '6CCQr8yiYmHHeklXpUyZGY',
#  '2t7nOIw5cbz12lyIgIaNDB',
#  '0JV7IEIaYfG6olLls5uKeU',
#  '6EhXQXTEPplSTzJpY1sGOg',
#  '6UwWFVfPms0FTNbkwfpOco',
#  '4dNirWTthDrYeTGxcpTzDm',
#  '5d41vXH0zvpwUrHrmqKqDc',
#  '5B78sGcSDqwN3X7olkFHn1',
#  '2AZ3TMtCVzbrOI6KJHgaCw',
#  '2rhpPt9vvIk7QG53WSLvnp',
#  '3uQyGzJkoJ4N0rBVuCCuOB',
#  '6o39Ln9118FKTMbM4BvcEy',
#  '31RYcUDhkqkH1W2xxnzBjY',
#  '5dcxuUQZI7nPldcNkxAR9v',
#  '7LZN7FkxHZk6maiN6NdI2i',
#  '4hDJrrN4g9n1w1q1DrNvgJ',
#  '3izLJdSR44HQzbfq9KePEM',
#  '1sFNjODWdOfuK4KqzrF8uI',
#  '1i93Ig32IZ4xOC9yya8Hus',
#  '52EDC32R0WxNs6ju9VUqLj',
#  '1emHwDueprGQh7CZGyi3gC',
#  '7a2GiRC34hswlfYriK0o6L',
#  '7ijMo6K6uLdgJqGdj9H7nG',
#  '1TvNcWY7WwPLQINhimxycA',
#  '58PWl2rA7lU90UBvDufzWm',
#  '2cN7qiHMJflO91pkG9HoO1',
#  '1fF3kyMbwpWXsF7yuN2Na2',
#  '0D22PG0awRmq6XlCicjRdO',
#  '4vL2P2XmNAdVRPPCobm4OX',
#  '4jTiyLlOJVJj3mCr7yfPQD',
#  '0VzKg8VHyLf83YgiyAetad',
#  '45uMioMjbRjygkXbSOkoIq',
#  '4VSJr3RHWy1ApnCxzuriun',
#  '4q6dqyGM25sKFU8nYAGRe4',
#  '4WHKtppIjpkBhXlHYl2JyO',
#  '2pcMa6CAODei0Q0QrDrnGa',
#  '4pKDCHTn9PX1kPL0Ou2Pne',
#  '4bxrzL9ZRj3WEouHhQU3ff',
#  '0nFosauGU6ARw57fvQ7cgg',
#  '01R3dELmvQpeCgQQGHQPS6',
#  '3XQgT6YH9iiEvsf26RAaWC',
#  '6R9KBVibYQz0OjFSDlPdrn',
#  '0JcKdUGNR7zI4jJDLyYXbi',
#  '5ZGM626be3ItMW4UPjfqdY',
#  '54TMMZ6ILa0d4IZ3ANQ7Fs',
#  '0Jc8qF1mUPo1A96HE9QxZz',
#  '0tGQ82X2sKge6qburuenA8',
#  '3mMmAS4MzTVAOKkWPn9X1s',
#  '4uip0lLkMKl1nwchsdXs1r',
#  '0q4Wvh13msslMC0awO54Qw',
#  '4xwgDYIrg42f8yKPyjJdr2',
#  '69iCzgBmaIaixkbajyrlyC',
#  '4uB28m7RAflobYpnLMb6A2',
#  '7miy73aP7NFhj8PL7V4VqM',
#  '6RBLcDQvA3VgQ8vHoXoo0v',
#  '1WywY6JdJcMlswZpqUPhSM',
#  '0ON952urivl5pUtUg3ExJm',
#  '4RbFwfeHwtkKfuVbGCY7F2',
#  '4gLYQqZf379ZMg50uR6Axh',
#  '3PsenMPVKqldiE2vq30UCq',
#  '0z25tUQgEI4cIyNZ1TgWig',
#  '35Pd77NZsD5jbqN9BHzWK5',
#  '6niFK347hm2Hwyy2MpBedq',
#  '2XGLdVl7lGeq8ksM6Al7jT',
#  '6XN91pyNTEtP2o1SZY5Cwk',
#  '6qWghjy2JTn4tnqSyagJGC',
#  '7jwBG3Ay5XMXGt74U1X89J',
#  '7ilc2TB1RZXbQJyFs5qCiC',
#  '0ydLewlsTax0SArEVPUIqi',
#  '6FWtmmLX3pJEhKdS0OwPTc',
#  '5vfIDmCX6GrF5y5JefwsX7',
#  '1obD012YaIAnvHZ3rvM4TS',
#  '5daLdnFH0xbIxDD0l3bKpG',
#  '2t34JLaa7IMm07Ut0Z1Vi7',
#  '0XZYP23bWVbwYsp0wtYnrW',
#  '75NCNTwo4hEcRPcHzABKhS',
#  '19Kz5zGwIu61QLEyMnlZZk',
#  '0ZljhJQbm611zf5ttHz43n',
#  '0Mr36KWkYYXqWHyAhkdF8w',
#  '3RWYPQpOdC4YrZJCrFWjZi',
#  '41A1eR06c1MIZwkfkME4z2',
#  '6bc3Z851377kU4Jd7xAyqJ',
#  '7t2bFihaDvhIrd2gn2CWJO',
#  '47VIOQHt2EJ05M1PwIhsBY',
#  '27K0NTi4jiLavC2buCg7KE',
#  '1gw3nz0tcMNwMO2ZwFT8OE',
#  '44BGoGw0sUc0Txh8Y4ZyFg',
#  '3kETWJsuc2ZtrVnx1EUHzd',
#  '3ACQkIMv6nGYHRpPGyS4BK',
#  '0Ov7lkjwIG07yduENnYDMo',
#  '6yfx76QsLGsfkaPoCFliZ5',
#  '4YbtI1eBf4RYNGw1foeiOu',
#  '6R4flNWy1pWkjzwg3TCDlM',
#  '3AnTfM2O5kUtlZfZ5O3hyB',
#  '00WYhQfePiig46dGdKurff',
#  '0DtItzol85j6j5F9j9V36Q',
#  '417Tsbh8ZT6sZFunsW86zV',
#  '6J2aa2t6SoYZbd6PSeN8th',
#  '4tTTwVxeUthDX37BUw1plJ',
#  '3PHLZ5wmtyZha1pp2405OT',
#  '0hIGUS1PQbv5NIrHIf6Fza',
#  '2CoGg71SqwNgriNkOLClae',
#  '74WfYekYIlUJK52HF27Vzb',
#  '6LVvlj9lLuyR9Qg4HryJrI',
#  '2elAyF0DLb10MWj76pU6pP',
#  '241F15l33UW1B2U98cotho',
#  '39kNd3YjHI2s8RBOcmtz0f',
#  '5u3r67mBw1dGXsN73MNNn9',
#  '1k7o67gk8hle7UfwC4t7bo',
#  '5QREkNN2kAKUsXppK9Vrcu',
#  '67qVKeLbL6IyHAeK5qoMzP',
#  '3vVkxjrTP4SM1Ogq68LoXW',
#  '4FKvX77CY4m1zmnXfWwim4',
#  '0TGA69v94LfE6ZZNxLzROZ',
#  '0TzaZYgwpW6Znv6msEQ5ET',
#  '58Fvi9zFWZRZYBaywJri0H',
#  '5TrfusgKC1BYic5LaWCoKm',
#  '6I7Rx2mZ9zARHGuPl7pye1',
#  '4iOFENARPfS3d6P9rCQ2to',
#  '09eQldP9e1ePBlc83Vylkm',
#  '7oanidqUgZO3GxXugm2ucC',
#  '4SYMibQ93bfzOk6uzkF0dO',
#  '1OkKdAIxbM7Ic0dJ1rXw2W',
#  '3jQdNmYNZxfJRwpi3Hd265',
#  '7aHcoaN1I1ZxKmZrHO2X4M',
#  '5OLHaRhvUdVmv58yVkBMiK',
#  '0r61QhigETeOXpl03u1nSV',
#  '2GXNOmYn3EAf7xcFZsgg1P',
#  '74hM58NEw4o6SNKqBBI7IL',
#  '3vXRZhHnVB3Z5scbRgH1ah',
#  '6wxGZ8D8lAuJpocaTAVVyL',
#  '0C4CdjZponKJGIaTvLVP53',
#  '4nGdWMAi7zChqNfuMzUHxc',
#  '4ggPIxXwOWReIBfyCVW8QI',
#  '5nCvxR7ur71JZIOUjJITTj',
#  '6AXIgQRvorhGyeBM0Jby9E',
#  '42qCWNVGjcCYNVPBInBLMe',
#  '6XuClyVHchX96u6KV10NkE',
#  '09OSyzWjBxBaQqEH90ZFfJ',
#  '0GpkBFuZzYVvyuSSIjAKFZ',
#  '5koyOdvQU9AUgPMA14N4mD',
#  '0CsM8VGDi38kusMv3pxyj1',
#  '7BC5gPMaUq1tRowfL3h97c',
#  '0nLOl4fSiBZKGFla5pLUtf',
#  '5OwOfn0Ihle2WLudoH22wj',
#  '6GkC6QyJ5xGwIy5H0TDxe8',
#  '4Q0CesDHTEoo7HqgE7QPY6',
#  '33d7n0d2Ou4wQ5AcLrLTav',
#  '2aODUMrXCZ4DD7A1uqogn0',
#  '6fNID7koTl1dZBCs6FmK4E',
#  '1oX2F2w07GFaLsa99DD5q0',
#  '6BbINUfGabVyiNFJpQXn3x',
#  '7lWUJpax919G4JdaFEVmCy',
#  '1HS0wlHdPGElgTYf81bA0S',
#  '0TRANsH3eagT81SFfWbf6v',
#  '4SCge41oDQOTIcfmhnYvAQ',
#  '3NVTVlnM6LOvDIVswOjEqV',
#  '1jmAqm1VJ6Sa3fnuiSSrKa',
#  '41nfKxXxJtf38uAk4DNy1a',
#  '4wgVwhGGBghHADrwfgOBEX',
#  '2WDEfdxBRrLXxBmabk6vOJ',
#  '6u8NlrEisjuQv3jPuWpHI7',
#  '78MI7mu1LV1k4IA2HzKmHe',
#  '32csDpGNVJu6lEP77Bg5FJ',
#  '35gkASz2Cb1VryMGIuEPjX',
#  '2gjQdYRk5A17t5pNxQXmuN',
#  '4xxo9sAIeVTKIvs0iehYqG',
#  '2BWMvuYVHM9Mvir0u7QTLg',
#  '1FipIh4nPa9zKMspunsj7M',
#  '5ra5c4NPCA4szK6hBbMs4u',
#  '02oflbh0MIscBQ0roJdo18',
#  '0YZKbKo9i91i7LD0m1KASq',
#  '2JwJqDEqC5IPl5bN3klNHD',
#  '0nwfRPqSPKxrcncIbOF2DJ',
#  '3QQH3sINjCT91WavuMwn6S',
#  '767rObQPgUNryNEu7HBnqq',
#  '2SWn864dJI5RNyrp3F4Kp1',
#  '6Pgkp4qUoTmJIPn7ReaGxL',
#  '5wr0w6LR2Il09Wfp6O2zkT',
#  '2W1wZG52PIlXihmHnNXE1G',
#  '6moGMWt8K47pryh8li1YNF',
#  '4YKpITTA6i2jmY9JlRWgOm',
#  '6mVJRgyXJ3eAy6EViECJyW',
#  '3mIPSwEUWnDuyD4LWl7KNJ',
#  '6J2YaJHDghkEFAEq1hui3E',
#  '10ulbdcVA6ptYfxbEYpAah',
#  '0Wzp5pWPoX0YoBg002HXL9',
#  '402QvyQvmXEEqrYvHP3bZK',
#  '395ZYCrLELWM3MtMzGskaF',
#  '1WwO85Z0H144SW8RDSTmCo',
#  '3ItDoNvHxDeCGPzqHQNSjl',
#  '5DMGnZllsLYdfd5dvia1bz',
#  '44WBNnkJAtTEWIkmrco6Mv',
#  '22ZHATFd20i0h5nCkJIDgp',
#  '7CuCP5OoLH77hJTibZQE4r',
#  '65LeJBEMVBGJ8u68Cw8LXZ',
#  '3bjCcWDx3IdJRUcATZt95n',
#  '2Srd8Jgif3kc6ou6Z4pSYJ',
#  '63PgfGFgAZUEzwGouciEC5',
#  '25CZJ6UB16xuDXMQulPwtt',
#  '4O4WrsiKj5fXuCs560vT2l',
#  '7rxcvBPJP7mShFfsLigSWW',
#  '6qFn9wdfeRYwOkYSrUt2Iz',
#  '6YAIC7MUa3F0KoqsDgkfPC',
#  '6PPhdQDlCx3SbVYkKMlb74',
#  '28UWzdVYFe36w0GwDJlIwJ',
#  '7iQ6KSGUeYY54zVpS6nn1b',
#  '7qoevFlh0HPPt3mJXoTJoZ',
#  '77p1lFItfo02snfx5carb5',
#  '2Ll44WxlG2eiqL6NtEnf8M',
#  '2dLAN4OozcSRpuNtVXJtnz',
#  '2ltnjqMLJJz9MsXLJ3yLyt',
#  '024h9MejLt7khAKIJ5rOif',
#  '5zQLjkuc2TuFdYE6NhmqS1',
#  '4Nxid85fmQidPAY1ZD8Bo1',
#  '56dg6Wm1A3pKoSfOCaYr8H',
#  '64rUORJh4zikFaieRu9xVq',
#  '1G9jeUXQNewsKfYPAMdLPj',
#  '3mnVgyzn5HC7Sqkn3B5zHs',
#  '6Tbyo6GAgUWuUBrUrAnC4y',
#  '1NpDnkQO0yWxTtntrC0UNz',
#  '5FwfZ50EhssASpCHcgnGvd',
#  '09kdyHIeoJreAxzQgWnj1k',
#  '579ilCA4Mq7t8UCpkFtYYV',
#  '2UVkhMbd2T3lV4ftEgy4Iv',
#  '3KtCCE9JqkfNE4Ld3jFVWE',
#  '70wFqhcAURVcjgMMx6M4ak',
#  '3yZTUB7FAoQG4PZq8cKyDP',
#  '6ej9jEXBeQI7PTbx68KHfi',
#  '7EMZSshbiiPkhR12fwOt0C',
#  '3XtwqL0pHwxVPrRBJnOauD',
#  '30dxVfMjlhBY6fXo3ThhJM',
#  '5mY04rUWixYG9amFzMJDhI',
#  '7aqLcSYNyo7zHNCdL4X1y6',
#  '2L9PjIRJJ9I6yTDUtUKVcf',
#  '5oUSGQNbFO8VpGb8j35MUu',
#  '3XNwaKqSnAirzXN2OQGF3d',
#  '2VnrlK8fagFRb1SF6p0S6g',
#  '1zBpuHWodpDufPON9nnxLY',
#  '3acRlI6blIFTqSLdPNoWPG',
#  '4O5GKVbnQ8U9BxYWu0hIug',
#  '2FNMqr56jFSLyI2GcKgM68',
#  '0QDtN5ifLue8gO7DP4HGyv',
#  '0u35Dpz37TY2M2j20RUdMf',
#  '3VKs9auDQSkcN0EWZrQr2d',
#  '3EcsBjwrCszsbN0SME6Wbi',
#  '6TjpGzKvek8CCRa8xwxXDm',
#  '55Mx8N3JKrvr6sjGRIBfGL',
#  '0B0KaRWxOGlVkumLXIBluG',
#  '3yplsfpJxafV8aRe1XA7yL',
#  '2scIG4pnqvCStKHTZiWB0V',
#  '0IiMne2pv3yBkTnaJUUwNA',
#  '0Oho1Elt6nNyiHZyZR8OaG',
#  '0ijZ0j6YDhfOiyTg21uZEZ',
#  '0WPc1cvp5VnzNxJxPxQ9AS',
#  '5CEShjK3uYlUoH9tPpgk5w',
#  '5xTt7WCmlfdSa9aP3MV56A',
#  '21y4MAL3qi5rjUb5IIKqrx',
#  '40qGH4aiVeaFW7qIPCyTVa',
#  '098h9BfQHAky0Wo8NzhpOq',
#  '6sk6bCM7bhpVIJPSXjv1rr',
#  '6CCG3ZO0TS924yKQXDmZgC',
#  '5VAb9PUHC2VgVtyjWAatsb',
#  '1gIoIq3RF1wl3Pp6d1Clzb',
#  '63hfQB7oePVNI5mSuWklNo',
#  '2HjRPTUazr7GjzLnmqdsXi',
#  '1bx8CKOpJ6qHmjUtqvMiHj',
#  '2rxE0Ip61QUYXyszQ5vb2I',
#  '53bpRfVMHVSORk5HpzMtB4',
#  '4zYTZvtcww7OWKie7fxA9E',
#  '7sZa3zvNoLZI76DNhxCbeD',
#  '3HTaKftetB9nQ4Vv3KnmvU',
#  '6TlSCetIwAdJHiyenbI0xu',
#  '0CXOYEN8m6MuyVY0F1vJTb',
#  '049Jkya24EvBHX1rUb96V8',
#  '0nj4U1atLpsFiimJSZu7Qq',
#  '64bOHAVAipEaL9KSvBIl34',
#  '2qqCS8wH4FNtgH7kVmF8Ub',
#  '1yvArCvZLTHiawRdWKSAWj',
#  '7b1H2bjhBYkiqmupgYL9KN',
#  '0spc6uqlps0sz238P6CHoV',
#  '1IAU4jsA3rOtmZl6t1nL69',
#  '74AYr2jEMxdPHIMZJvlTgR',
#  '0cRmdEwmuWPcdjTprrZyFl',
#  '7bPkugM3pcS49I0b1UJP8Q',
#  '4AIe3sG96eYefU5QVbN7H5',
#  '3YAwL2vQp6TK6PhQIbtbOe',
#  '1heVWF8ZRGHytzkprd8rj8',
#  '5KbW7FzoHHQ7Stx2feIXTA',
#  '61vPMevL4UysTHUKAEbV8j',
#  '1rdmfkLroz0Ndm9yVmhbFj',
#  '7r7NaawVVbk17eUCNnI0u8',
#  '22bX2FwXSvG49G0bPWm5nc',
#  '3f58KSAwTMsRl6zAWHAR11',
#  '3OBHpK5sbRBj3xQLCFcBLt',
#  '41AAlcWHEcqRJIoltPPuCG',
#  '04IeGLe0k2QmXzTt5bmMtX',
#  '2zkZcJD7k5IEAiXop6BUkg',
#  '0E9lk1H6Nvp7Ta6KolNELb',
#  '3lNSX9MR9pzgqKfype7exU',
#  '1kEx0zLD9UhkOSSld3hUYm',
#  '05l1lzf4SSeeKWx9l36f7h',
#  '2iBXWpYsMM1TowNOD16sVY',
#  '4b93D55xv3YCH5mT4p6HPn',
#  '3RkTzoEHe1md9i549rJQVz',
#  '4WXNawopADYDqDfHHcAiUP',
#  '1cfMdMmJqBlLn4auevv0iB',
#  '3ox2BrDJFuRDlq3lHY2kyD',
#  '4ltXPf327ewFdmTPp5Skow',
#  '79534UgfcUxAbzLt6zLh08',
#  '7xVpkVkd1klTzLJEysIR7z',
#  '7DhR8yesM1hsw3EymhzW5Q',
#  '3pojMN6t7DvDSmVMU8cfsG',
#  '5mE4VHS820j8N9vnGlALmg',
#  '5j9yOfRB2s6OMS1YwwYiMw',
#  '1zGQ3I71GgkwLytzEmi9Wa',
#  '506hY0WGtPnQcNYt1pZJ1i',
#  '2XEDvwzY9TymhYPqi2y0GL',
#  '7pAtHdGQONucpN7PJfnXLu',
#  '0qyAgwtnMU6AOszUw0DWTe',
#  '0hXHpNiW5dHv21aUhYDEnA',
#  '1ca1bHaFBBKYLKvRmOuRpP',
#  '48WNDBWPqyaVx69otdQ9Lg',
#  '6kni0aRaJX8NNu63sfKTmr',
#  '1cbNBIrRWP4PlJeyjb7ZmT',
#  '0ckuRLjCOz1xuK7DxE7Zks',
#  '6vmAgl2y9MpoZKrVUXrPe5',
#  '4dskPbdHR8PTL122wXMpZB',
#  '1HrnYddHKVUQl72KIS6BKf',
#  '5o4SqGekEfvdkNuOVx5d3S',
#  '131Cn3DUEl3y5ntnIVvNhq',
#  '3LSna6W1dRf2QbsUgmRoFf',
#  '3OhD7uPlcS0uJlZgvEWs9N',
#  '5uBzy8sOFgWdgA8ubUwuiw',
#  '5KXKhCfPNS4342ly8tTf6w',
#  '1lGA1yVlhvrbyPvQ9tiWPh',
#  '0dtrZqWXAMjOCk36dwVSIk',
#  '5QSmrz1EXxcAgytGCCXU0i',
#  '5DfWF0jqMgZDCiu9zJENTA',
#  '3FwJ6vxxKhhvet3DM042p9',
#  '6NYZGuqYGCz5e3njONKlHQ',
#  '2SkJKMfjpYsNv0KWOxiegX',
#  '610FzmkhFSsORpECZbjT4X',
#  '0rllda4hA3GqRhsF6SazEw',
#  '7zSwlR4q02oXqNqLLn1tGZ',
#  '0TCyT2ZdKfVJbaRns9kKZc',
#  '3KdZ0h53B4Zig3WcG44Euj',
#  '59rzNNiQISFeH3ktzhyOjr',
#  '5ZMnNGtJCD9nTyuo6F1r9p',
#  '1SYwQft4iEJ5tAZcYg1bUM',
#  '5wmwWlwyh72ZvNrLIy8FjD',
#  '2QheXUmdf7J59aSVKcHgoR',
#  '29VrHhpC5AS9b7XJYDPhqb',
#  '2oGXbxg0ZapA8fwRU9rveo',
#  '5GvWpHGm0udlQjFjXUa0Ad',
#  '6zuRGCIpH2zZETd7pLQ7yG',
#  '3dXF0pa5oF07WI6cX9fXrU',
#  '50PB9YGCpaAcS53uzSePdr',
#  '2Qe16TZa86Mxia9cgSbZoz',
#  '2BBH59nyfRuXTC8rpYEPT0',
#  '6f3OYG5R630tjwFIHIE7j2',
#  '4SRHUPhlL8OfjrBd6OhTrs',
#  '6Q8FLlX9nZZRBdmEpbbGKD',
#  '52F4M0jGBdMet8jqWdpmdg',
#  '39PMNhqnKZwOeMdyLNtjQB',
#  '0JgpdKK7T18MmjHBNasbWR',
#  '1RSDFzW5aa1RWyljYsa9tS',
#  '1ycelhon9reMwqnoISqQzQ',
#  '1FYmhUL5kwz90MddCidCP8',
#  '70S3u367gkBLnWWaNF1WcZ',
#  '0vhOJ8a3M2LWnBNrDXJKDl',
#  '1d1Uc9yNUMvUb0RbakGDt0',
#  '0jPYzlUWpk2quz40bawgjW',
#  '5YqpHuXpFjDVZ7tY1ClFll',
#  '4uXR7YMfwMmFSPUWJHGDY4',
#  '4ft2FN1nb6lSGpb4IWc9HC',
#  '7qnyLm2QMpVzXm0XJQKzOx',
#  '5cQIrML7iJEUsOCNsHqWlB',
#  '0UHgJn9wcpxZ8r90Ospbrh',
#  '7xy0PAZxzGDOcYzyptvprd',
#  '4urwpZN2dhGDqDXUeVLAuJ',
#  '0gPVwXtUoT1Whc9xtd09PF',
#  '7BAhzTot56D6Cx5zBq4zRK',
#  '4507W8oK5M3FgEFizDqyMm',
#  '1P6ClnjGi6RK6vGZj8LsSQ',
#  '7mGFQ68R0o0razSwPvxqGB',
#  '0Ad93Ruu1wGsmwOKa3at9f',
#  '4yDs61mzPcTod9qrBUE3H9',
#  '1kN6Y8g8TomkObrQfhMGkf',
#  '2CniHGjlpzDBw3Skj7oplp',
#  '2rXs8yPV06s9gSofUHkLyv',
#  '2Vy7Ly22pMm4d5xax6gEwG',
#  '3zsPgGnDiaEXyFr3GO1HcW',
#  '6Ar5ViRL0hAtwunNxjLvpt',
#  '5D1OXxoEIOSv5eWsw4vFYP',
#  '4pmtGfdrkfftP5kOnbYuXE',
#  '0J8A1ZVyJcRZxFNvtp6jRh',
#  '3rWBerJZHd5IvS6o3dQEk7',
#  '0U9D9G72bS9xo3kevc0aEq',
#  '4FCI5vsnmWNaBe5MMVn897',
#  '4uJTe6iIEWjW48x1SiXl9f',
#  '1trTUXfLUoIlyVVhvnbp5E',
#  '2PZgh2Hjn9s2JSpdPB9ti1',
#  '6VWUOFXGwH1OgyPrfRONrn',
#  '0r0N3W8MbLUIv2biTnx1WT',
#  '2Q2CZbdsJ75Ev1IUmcJmvu',
#  '6MMikkxsR7ELTD1w9IKDdC',
#  '7Dydh0F3XllKOswHKZG2Aq',
#  '5u9NUat59IiQFVEzZ4r3Np',
#  '0f0FXdyHWAx3q7XyU9oLMI',
#  '1FRPO2u5RWCSJHv1HLS8XL',
#  '4Ux3HFLGu0lNBnVErTdNo8',
#  '7DcJ6fEBb7BaKuYKTwiDxK',
#  '038jgLNIvp7QQNf5vILf5d',
#  '2JKRZGp4LwT9GGbcXtx2sw',
#  '5MwAvp85J0t4PDqcQ0DLNQ',
#  '444nR6LLERVxjgzUyZSVNp',
#  '4eoHuUZ7Y7pcPehOtgEn5m',
#  '0qnOjNW04qpcgXqD9dwru2',
#  '5ONVnHYT7srwxU9UDsJH2k',
#  '4Vdku373yGR7pG7xdoVAeS',
#  '0QB6DmkH6n4DOnH0Ltynrc',
#  '0jIHgUfojekFEuGobepy4H',
#  '4IvgU9uF50YnVDaKU5WkSn',
#  '4YetrvKdYwgQANVedMth3F',
#  '0YqZ7OvzkjADdTx6XsAN0F',
#  '7wpYF1ENhr8kAJJsvCZDHL',
#  '0pwF4WOZdvnXpSwBZXp1iA',
#  '3pzsfTChFWRyxXXzRkKstC',
#  '0e7RrbkDirLHxsMlgcJ5bJ',
#  '5Hroj5K7vLpIG4FNCRIjbP',
#  '75RnJ7AGlYm9N5k64ZY17w',
#  '70pgnFns8UgV5bA6h0aIH9',
#  '0SIFpQOZkxPQUjcJd5CC5O',
#  '2tJZeHNERyf3X8LtZfwAGZ',
#  '7gvFV0ndhy4s79EZSGIFXe',
#  '4EhbLHYOXzEoPmOfaVoIIW',
#  '24Z9YNvIlWNjYraAqyUgSh',
#  '5Vkdh8GfdXmwyJjzPewMWM',
#  '7cyBdix7HId2onf99SrJBV',
#  '46gKSJCAUa5P3PKDaLyt3x',
#  '0v2p5ElZ0p9XZPFnc81wwg',
#  '7i4FlzwZ8FhdmjlIOS6Mp4',
#  '3KznBa4MzPvqOch1kT9SvQ',
#  '4PZzEAYfBb26M5Fhm8xbZd',
#  '0NG2kF1DyL1fbSvPceeCEY',
#  '267R5FQjlJJCgxSlXerVV8',
#  '1znYwsMLK6c6r2DnZWHsqS',
#  '4HaHRDxay9H9VtVKQgxx3X',
#  '1h9Bx0bcEIfiv31E2G58Hf',
#  '2AIryQ2jx6YYHwP5y73tQM',
#  '0ehVk4Py6iyLpfruxVYq4S',
#  '1wl3u4FrzcuBv2LQ97Z6TQ',
#  '5lsdQwpGFNzg36l5wBKVPU',
#  '33471tzU1VghDg9zNgGRpz',
#  '15e3leRc1c26oStnjjiex6',
#  '1dlgaGdQXmsYKMRuewIZkF',
#  '1ry1CklMZ21SLbdcBaRB3k',
#  '6dDcfbMUFkFDk6x93kITY7',
#  '2qhASBzpbFhPRtrnZ5lLnz',
#  '3tdpwiQQoDsSvA9etI99aG',
#  '73dwPm6yqBlKMUekCGDvdA',
#  '6LEFWv6jPUy0uoTY9hN6wD',
#  '0aHWzIvtnkG3FVcBoFQ6BG',
#  '48NSxuARjOaGLSOw4Ojjg9',
#  '5fEB6ZmVkg63GZg9qO86jh',
#  '53AD8JznNIb0jUZvwFY6MB',
#  '6HH1rzLOFz4GdtLDRpqKdA',
#  '6xOZCV4EPCupXwvqajSKzq',
#  '0j0yQeR52NUatMLFdkNgKr',
#  '6lZMSnCPm2jStSutrq3k7t',
#  '50dndMFNoQcxGG8iN2HVbd',
#  '3R7bfoEKPkxaukeC3ZSn4o',
#  '69iqQSyp530ldltF23gFeY',
#  '0C2GwtpfsXGT7ETnFRgDc7',
#  '2BQbt4lcB3dJS1yv0Wuxnf',
#  '7yTLbcJ2XdLQjb8FH2gBJP',
#  '1TDIAHBEvurNCb2D2fvMzr',
#  '3QslWf6jjw6f0by37Zrupd',
#  '1W3DDO8csBRUTdNITJgpag',
#  '5w7486KEvszSIWMeTgdY4X',
#  '1V53hVrykkJRV0qd4JUVjl',
#  '08IMar818SkF4xZmkNfbi1',
#  '4MpRbPKlRrIHE4TVbpggWA',
#  '6I4JVo9YbR9LSnb2aZq9yP',
#  '6XUbeoXKal0wPuKohIeSfp',
#  '0RJmnZ23Usaa07LPUe4mGb',
#  '4ex2ha7IThFZY8isfGPyHJ',
#  '5fprEY6WEN1wvFXkgfb22C',
#  '3jZvtT36yqTRiCQfv0IRsU',
#  '6uGQKWdjmKvgH1QdDCcM8N',
#  '7nPMsFa65oZMAUHNuTmTVP',
#  '0M6ubxqeWNNB6RgeobpaV2',
#  '2jx7xjmIDRlKX6EVjZoqYf',
#  '6zJms3MX11Qu1IKF44LoRW',
#  '6g7xgIFhsU6G2OkRmArFNT',
#  '7cherVO4o3h27dMT0GiQbm',
#  '6SWQgorfQUePtzedn7btr4',
#  '2YEPUm6I2jmrh75dIKJou6',
#  '7d1ustAIlXG7ht5Q4IOv7s',
#  '1wklGpzn3imtERdVytlZoK',
#  '5JiWVG8j9TmqwZ8zZGAtjZ',
#  '0qI1W6chJgvrSAzAkX9JBa',
#  '6w3RBzYJsYj81ZkuYlBeSM',
#  '1THUJz0GXtFR311DgQIZmX',
#  '4V04bHiCEVux579JcZQDDP',
#  '3hplBjBmQqR49L8THyjTdb',
#  '1a1MUU4v3BOfsPBvFNqt1Y',
#  '5dinp9mPq1xH7maN4iK722',
#  '2yEZDWES6x7CaETRcFmr9t',
#  '2RiqsYVO1YN3PZHhXz3gHK',
#  '2tBd67cpkdg8jpr8bWI8fT',
#  '6IZxBM9ypX89dYOCLhFfBg',
#  '1wZpmkvPVQXdBLc6MnIpJi',
#  '6cuKyevjNVrb4I7BAA9NTv',
#  '1iXtpeHC0i6c7JBrKi3yaq',
#  '03lfYbaAcL3eG7lo0g7TiX',
#  '13Mh55MPFYy2O6uby9061n',
#  '5jnqqVwo1lWgU7dLxnPFPO',
#  '5i786tCK4z1NarDDfsvfiI',
#  '7tHL2RNd5r67bKd5WITs67',
#  '4YU0Q0IBqTq2PUnGZJH7Ki',
#  '4L2lzMYxwE4ObPozyV1idl',
#  '6REc8idTpdDdMlMIcnER2F',
#  '5ctk3VJoHoURSiwkCJn2bf',
#  '6Ub63208eZVnT6UPQm4fGH',
#  '3sjUUxnlyM8TfZYQDOxNaK',
#  '7qvVHhzqlsObMAFmofBILE',
#  '5wTFHRvJObSDuvNonvUx9T',
#  '2WeGSj8M1jVHpjtaOcV2Mm',
#  '6bBY3Of4qMlYgjdVsl85iJ',
#  '2e9Ttzg4LAj9SO2eYUKi29',
#  '6x8OeZQWzLjuOIWkFrItNc',
#  '4dJ5dViPmuNPxOnxbwY1dr',
#  '3vrsejqNj2DkxLW0qCcovw',
#  '2hDQU47XuGq9CdYRIQD1m6',
#  '0Wx7Hxa7GMfIgksIvF6rKP',
#  '41j3QgPNvLSoWBucJuInCZ',
#  '5Tq8P4HOkAk0QN3QklEfvS',
#  '4hRnEc9d92ZoFMZtSQuTVH',
#  '1pBAsoHy7eN9aeVCTAiKua',
#  '6fdwvUnKiLv3IIAWaLtol0',
#  '4REDvmUPUTCDmGH6JoLy4I',
#  '5Vtq6dHdwbjHqifCeSL4d3',
#  '5HVlLcsj0TD0bZiGYQZ7p2',
#  '7cophW0FqeDEEW9i57WBvL',
#  '5DydMbw2U5Oh1OckJIsniN',
#  '1HSVpIU0XU1WuwiBLBWAZd',
#  '2nfV43EMA8f0ULADYfiaOO',
#  '1wVUjggKup9hP2jd24gLSg',
#  '7l5kOMmACRRDCz2fmGTCtV',
#  '7mnEXpBzjbW8dF1OuLBjk8',
#  '4NUtmSWusJGMtbwuqWIXxJ',
#  '5a5uTOmY7kvRUGkqvRYLs1',
#  '3mJf0LJWgUhqn7v2fUmw2x',
#  '33JZwOt4b0YpQuCYiEDP6k',
#  '157yhuyYm0wY8O1cu10u3U',
#  '2SMtZMhj2eMJoCgS8iHYbR',
#  '4xy8oQb0lmfsK8QhAKkAkl',
#  '66Ra2l0vQTGFBcCL8vUwlI',
#  '3ntrdR24dLkKrzSGRv1FlH',
#  '4X0gLfG9AtY5Kja1Ejbz51',
#  '36JEJ923q81GkE88VP5WAD',
#  '1jy0RbDHyBMTupSdc98XbG',
#  '6izEYubQaf7odJ46scKEzr',
#  '5mRLJi6U0ekpw5mLSFyxRH',
#  '3zwmW1gM4E8FlHXV5nE16u',
#  '6kGqD94K2oVy5y9T8PuQ01',
#  '6zd772F94reUnGHulNeEFm',
#  '3cC4TINErPyxCWtSN9w32h',
#  '04pbWoq4w9DLuECxvXnIwn',
#  '5f53FRJzkiXliPOv4iiXKe',
#  '6xO8a3lVqxwZkUZqx40Csv',
#  '1Z4heNalZg0ACcM6L8X25F',
#  '28sjod0l8HylkyQDY0kyyc',
#  '3SqL1v5qktYFJ3WXGzR8hy',
#  '15c6FHazmCDlUKixhYY7Uv',
#  '01LODLnhlfNphZ366BqKc0',
#  '22UhQSbYimuCnvI0Y07gFX',
#  '7nIWdmNYM3uxRtCRRZCCbv',
#  '5DOYik1z3Of1wAFfY3dYbC',
#  '7k8jcHrpVkWGjAh5i8n6jH',
#  '6QhDfz95hFd7HtZ8FmAF2c',
#  '5ukHmdUBB1anlKt7xmehep',
#  '2oGd3WCPWVqprUUnuGG5V5',
#  '20yYPHauVf0FFLmOYgRNfQ',
#  '0FnihOWrfj9DRlgWcbhuvp',
#  '4hIviGAPTxGm9J37bIGPlE',
#  '78JpZkoCEhniCtV3QTRekn',
#  '2AXMGitwouateYXKhBaSjx',
#  '5LMx5jWGZs2aUi7P4kwiTt',
#  '6hTBP6QLwJdxbKyLlLXrGo',
#  '2OmreF99DfVXmBKAP6726g',
#  '58gUarIKn9edEI75Fa2euQ',
#  '254GHWybHAnmmzB70OC690',
#  '0YSTRuZ7elW9CEBfZJW5Js',
#  '0IEZI57xAMEdWkCkxOVxST',
#  '5aDoUmxBsbdpS16alksb5Z',
#  '7KXjTSCq5nL1LoYtL7XAwS',
#  '1NRjLmipYrv39gWoqCl2w2',
#  '512No5uXtXbhNh7OOz03pF',
#  '0s0AGaTAOfQnvmGKq54oUR',
#  '5lsOpBwVsFI5rExHy5TVZ9',
#  '4ou3f7jaB41isbJkt6CF2b',
#  '5OUSPcqhYTOzpbXzoEvKim',
#  '7iLgYqNYFrztUt3VHqb89b',
#  '6H2gjJlwGS4le9EVilrrFd',
#  '0loPe5ZcMcwWSmXgoxKQzn',
#  '3bEKLydNVwHoxDqIDuxwvP',
#  '3B3lEqSzpAUghMbBqJPtyb',
#  '0Qlbpljv5ZRlxRaYYnsvih',
#  '46NtQJH1eok28bucLlHqQT',
#  '0x4rW5jv6fkKweBgjE5O8F',
#  '7tbL7tfxXXVK1rPwhVgjej',
#  '0QaQB1qBNYpTQBCJ10acJR',
#  '0ySxHGWdbENkqGdthmBxps',
#  '58smfvnOg9Wn7koHxsvJ8V',
#  '1piX68vNesm5gA3ZRM3z6Y',
#  '3ZgrRbLGUtmtzmubeiRRIb',
#  '2ewBoLnO91sQcZWpFZcAJU',
#  '58o22dVoi6lGqdJoMN6qnF',
#  '0MMdmhfFXpflLBJKq4cdYA',
#  '01kajEqjHkel6y36NTFgd1',
#  '4Bj7sPp72rZs5xZb8Z1RtP',
#  '4WZUWZ8Il8bzeJwPcn2DqE',
#  '7bxvSVLeUMtCEi3BdscXUw',
#  '3Z3QhZAZpqwZa1phsbQ3JZ',
#  '3B1cnD5CuR6WSN71V7Rlco',
#  '1hBi66N1p1QyvFTHjnH2jv',
#  '57GQHVnq4UIAgxU38lJwUC',
#  '2vvtJt1hsoxL8LeVX0KiY9',
#  '2oFMQdhYZUVd63DKRgJNVV',
#  '6sREV6MpLHTqcOmBK5mvYF',
#  '6qV95w6RYTspqNEZEIL8rh',
#  '27XaO1Nqv2kkDvZRgxS2OE',
#  '24z528iI9kZu5LbkLainjI',
#  '7e3KM7NU4FMdfSKolIJtMI',
#  '1ce4FaaSEAYzNNhzxDMy6W',
#  '5XgPoyXHAjMX1QuJQdUd2P',
#  '5LHul3BqTEwaLtHSbXOn5j',
#  '1wU7z5XE8oa66ZvUlYAKfK',
#  '1TDk2Jmi4dVZhm2dum3Jim',
#  '1QEEqeFIZktqIpPI4jSVSF',
#  '6jCvBgUfwTzpBIMLNKYiGC',
#  '60a5c4dDARPsksClcom0OD',
#  '0KNKU0I1iNOydBWTjbfJVx',
#  '0baCR9QLEoMBMDvprSrGQO',
#  '12zHEsf1Yxs7JoS8ZIEQRV',
#  '7cJJqEUT3UKMGHiJWFr4il',
#  '14Yt3KfCCbtpgUkKPgKJMc',
#  '29k9SMi3bZi1lhbGBLcpwI',
#  '2271qTmPggEs2srV3i4g2e',
#  '0pe2du168zXMGZJlMcyyIb',
#  '5P9h9gQlq8CFLRWI4e94ei',
#  '1V6gIisPpYqgFeWbMLI0bA',
#  '2nbV8brWogyKVqRhypvzJS',
#  '7kthOEffJQSYAIIh6BEAJE',
#  '4Jr6bqJapv428kf9X8NDjh',
#  '3L9ydJdO8k8c7yY6aDyTLZ',
#  '1zgZ3AOZ44i6CvMG3ocJET',
#  '1pkoB8ZiZymyyIvaZmKElJ',
#  '31xsMCE06e7oJkrdm3lkZh',
#  '0keVlWFK1GdVoZgs7rUJAh',
#  '35jHuMmxegwKtWbWaYFtZE',
#  '1rH6IEkxIjjm6SEN2J4rSE',
#  '0ls2HeVRI2LELC9uk43Kje',
#  '09ORSynamyltVPUrxJzxkZ',
#  '76EMME4l9yqDeCpgOYRoTM',
#  '6CqCILZtsQnTLjjgrDgCsj',
#  '6rOeRjwFiafPC2ABkrbbSz',
#  '6zsk6uF3MxfIeHPlubKBvR',
#  '3897s4XOWQczz0a0FOEiJy',
#  '3QIoEi8Enr9uHffwInGIsC',
#  '3qSlbAE7VfK1AVyxfoHNJZ',
#  '35nk4aQWsYv4WWjDEMJ6ig',
#  '1f4b7RKCXKv9dzw6y4d7St',
#  '5HZchgrpAreegk6UGs0zHr',
#  '6nozDLxeL0TE4MS9GqYU1v',
#  '32UIpKdyGzgTPTO8e5ge5c',
#  '1jOLgkb49AW3ssNKFue5J5',
#  '1M1DkiVCJ7KURGMkSXrZKh',
#  '5ku02wJA6WAbmCTq4lw3F9',
#  '2TV9fAIDDJ3dMwJCj1a5pc',
#  '5O68l7q3EXwILbdZReNVBV',
#  '7sIx70dGj3VBiHWr0KZXfD',
#  '5A1OTrmeDweZFegTTzOMDY',
#  '4pcweTeOtJdAPnmYCBrKKE',
#  '1Xpj3QviqIEVqPS2YbivL3',
#  '6R9LiK1WhfnTvFsVfusdQl',
#  '0ds1IdD1IEV80lg0L18mkZ',
#  '4kwuUFo8lGUblIDNbEqcfA',
#  '1BDdVN3tEG9QehTG1uaLrO',
#  '0wgnnUrp9GnX7QRFIZdWyI',
#  '6pxtYyPZ0bRGknKlughfXL',
#  '1BFxwXiINo27xuiWzxkG1F',
#  '0elJ9OdhVl2yp4WJrtg5mm',
#  '0esbFMCLPGXSglHyFEUqcJ',
#  '3XCVwgeAOhukOIc5DyMHlo',
#  '3KYRDZd40yQcvp2XfWCwNg',
#  '6tM8cMX9S4AyRd5sDDrzhN',
#  '64wXoxgsQgC4PCKnqfK6f1',
#  '1Y6Dv0tWYUP3Za2Es9FUL2',
#  '4FXCf24Rdhv8hTySqZI7iY',
#  '2G7V7zsVDxg1yRsu7Ew9RJ',
#  '7JYfuAtvkGkTunMMyDkrRa',
#  '2NKrjQ6CWIlcQQGoFtusde',
#  '4gEPgpyjzXjr0jEbaBNTgZ',
#  '2R5LeHLqX58XjEnKQfRjwD',
#  '56RJScHJonXRwzW1tiwFmj',
#  '1oGdVdYjeQvojGKDddxLQQ',
#  '4H7WNRErSbONkM06blBoGc',
#  '6kcZFOY1RVzgtqqiRKRNfa',
#  '010wMON8ahlPrW3Dl6mBpz',
#  '22ltjOc5ChCLWCjTjeBzs1',
#  '1GERVZcph8qx09OR7Wo1UV',
#  '3S3c2DmBhih5bOWciUPwLt',
#  '3GcCAyJ99VMzHiHnVqtTDf',
#  '6IB3gmytuTAjA1wJWeGXJv',
#  '4FzjmZXggX5L2pro52kHeq',
#  '0vHXbhx7snRZucmzjbpy1X',
#  '3lPr8ghNDBLc2uZovNyLs9',
#  '0D2jPX7b8uuHfiwGms76mY',
#  '4bAFo6r2ODMDoqM5YHV2gM',
#  '2BPEPkeifa5LoOg2Cq9bkx',
#  '7LIunWjL8aswDu0dIkvZWs',
#  '45PxuJqJBnPXZKLxoo9Apj',
#  '28jRA2mZ4J2YaUmSroYpF6',
#  '5V7kR2whvCp0TPkJ71LTpG',
#  '50VmHAA75eis870UrmY6Bc',
#  '23WSlGuBoTSyp8YjZzPSgR',
#  '6TodWdTSDfzwgYynTZSvJn',
#  '3qXcnzcNx45bXlWJzD730w',
#  '5jMHhjn0ijWcz1WapsnoHb',
#  '0dPDHAAgCN5fpITPs4ydEY',
#  '5z7KX2OZDPdxcNCwfirE8y',
#  '7kFMBTOVe1fBGI5PefWyY5',
#  '1nMKEA5cstslumoTJMVjIu',
#  '0elXIl26ZrovBULLTrEGK6',
#  '4uvehZNI8BxnmBOlG9wmVn',
#  '5m8xVZhlM7E2mL9uuxZpF6',
#  '4jyZHdfC75dIxqJgovAYKv',
#  '47DNLshKyfpfa9p6Q57sVH',
#  '1dZRSXQzK9y4FlV7zgKBb4',
#  '7kEcHKsKY7Bvj8QbNF0RFi',
#  '0EDIRMxCC8ByrL1Tk0LP7H',
#  '2XCFlSBeoeMmP1L5jBqnqb',
#  '4MtpI0iGIlBySp5KJLp5Q0',
#  '10NKz3n7v1Js6u1QJIL1qV',
#  '1vRtCw9u1ceYFfVhcBBV8r',
#  '6ttNMmXcEXz4G8PUs4Atpx',
#  '1opNhHzl7YYxo1szmZOLAA',
#  '6CfwYtEnSDgMxosLZ5Vbiu',
#  '68cB6GvBTKkxDIoJWVUb8Q',
#  '0k4V4I2SgUgUpnjbZZAsQm',
#  '485n0T3wbNuA2KdaQ889kg',
#  '5YAaLzD6KKGeD1iHVfGupo',
#  '1ZwyRRW5zGjt9gGOwSO5YM',
#  '6acDlNeA06MCVCzsTVGr9V',
#  '2UBdiNO7Up6ixXjLUW9Vds',
#  '1W0rNaAXmNzvfgp47JzcVQ',
#  '7w1SIcywoHZ5jD1QEbiWoj',
#  '68Dw31WgtmuN6R9ZqYW6O8',
#  '5hrxThzFwXQOb2UeIgSIBl',
#  '2QZXhDBcaNrzLBGZfp8an4',
#  '4y6HM8sGfhSqU8qa6DdWOv',
#  '5W3lGYtD3s5wtXK5nPAtyz',
#  '6aP6XO0oCeitDBeV2ZZbpk',
#  '2taU9obeNJpV0sDiiu3oNt',
#  '3xyIMcTIUiKYaonEpM8e2p',
#  '0Dsh8QOcNffWgSVcAnezUV',
#  '3a8P84MKJgK4deiRxWdMyu',
#  '0QyVMBMqqPeswoiWZOYDkZ',
#  '6TTBhxnb9NYT7cz6aLOkBy',
#  '2EpPgLaCzXNp49ZfiX4GMC',
#  '306ofuHiiuU1HxvVDDvYkF',
#  '4wN8JTdmoU1rLLXotGJZwU',
#  '3QjQp2bfAvLTCSi8Zhzqis',
#  '3CqdEcYe3xWopkzxQxiyIK',
#  '3xLGCP1IbxbA15StxqQes4',
#  '40vchayv9Vsd9SzRYs4yrE',
#  ...]

# %%
# we get the audio features for the not_hot df via the list of songs obtained on the previous step:
not_hot_songs_feat = get_audio_features_for_chunks(sp, not_hot_song_id_list, chunk_size=50, sleep_time=20)
# Out:
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...
# Collecting audio features for chunk...

# %%
not_hot_songs_feat.head()
display(not_hot_songs_feat.shape)
# Out:
# (2821, 18)

# %%
def merge_and_remove_duplicates(df, audio_features_df, merge_column='id'):
    """
    Merge a given DataFrame with the audio features DataFrame based on a specified column and remove all duplicates.

    Parameters:
    - df: Original DataFrame
    - audio_features_df: DataFrame containing audio features
    - merge_column: Column to merge on (default is 'id')

    Returns:
    - Merged and de-duplicated DataFrame
    """
   
    # Merge DataFrames
    merged_df = pd.merge(df, audio_features_df, on=merge_column, how='inner')


    # Remove all duplicates from the merged DataFrame
    merged_df = merged_df.drop_duplicates()

    return merged_df

# %%
hot_songs_audio = merge_and_remove_duplicates(hot_100, hot_songs_feat, merge_column='id')

# %%
display(hot_songs_audio.shape)
hot_songs_audio.head()
# Out:
# (83, 20)
#          artist               title                      id  danceability  \
# 0  Taylor Swift        Cruel Summer  1BxfuPKGuaTgP7aM0Bbdwr         0.552
# 1    Tate McRae              Greedy  3rUGC1vUpkDG9CZFHMur1t         0.750
# 2      Doja Cat  Paint The Town Red  2IGMVunIBsBLtEQyoI1Mu7         0.868
# 3           SZA              Snooze  4iZ4pt7kvcaH6Yo8UoZ4s2         0.559
# 4          Tyla               Water  5aIVCx5tnk0ntmdiinnYvw         0.673
#
#    energy  key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0   0.702    9    -5.707     1       0.1570        0.1170          0.000021
# 1   0.733    6    -3.180     0       0.0319        0.2560          0.000000
# 2   0.538    5    -8.603     1       0.1740        0.2690          0.000003
# 3   0.551    5    -7.231     1       0.1320        0.1410          0.000000
# 4   0.722    3    -3.495     0       0.0755        0.0856          0.000000
#
#    liveness  valence    tempo            type  \
# 0    0.1050    0.564  169.994  audio_features
# 1    0.1140    0.844  111.018  audio_features
# 2    0.0901    0.732   99.968  audio_features
# 3    0.1100    0.392  143.008  audio_features
# 4    0.1370    0.519  117.187  audio_features
#
#                                     uri  \
# 0  spotify:track:1BxfuPKGuaTgP7aM0Bbdwr
# 1  spotify:track:3rUGC1vUpkDG9CZFHMur1t
# 2  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 3  spotify:track:4iZ4pt7kvcaH6Yo8UoZ4s2
# 4  spotify:track:5aIVCx5tnk0ntmdiinnYvw
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1BxfuPKGuaTg...
# 1  https://api.spotify.com/v1/tracks/3rUGC1vUpkDG...
# 2  https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 3  https://api.spotify.com/v1/tracks/4iZ4pt7kvcaH...
# 4  https://api.spotify.com/v1/tracks/5aIVCx5tnk0n...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1Bxf...       178427
# 1  https://api.spotify.com/v1/audio-analysis/3rUG...       131872
# 2  https://api.spotify.com/v1/audio-analysis/2IGM...       231750
# 3  https://api.spotify.com/v1/audio-analysis/4iZ4...       201800
# 4  https://api.spotify.com/v1/audio-analysis/5aIV...       200256
#
#    time_signature
# 0               4
# 1               1
# 2               4
# 3               4
# 4               4

# %%
not_hot_songs_audio = merge_and_remove_duplicates(not_hot, not_hot_songs_feat, merge_column='id')

# %%
display(not_hot_songs_audio.shape)
not_hot_songs_audio.head()
# Out:
# (2821, 20)
#                     artist                              title  \
# 0                  misfits                    american psycho
# 1            elliott smith       somebody that i used to know
# 2         june carter cash                     juke box blues
# 3   emerson, lake & palmer  karn evil 9 1st impression, pt. 1
# 4  queens of the stone age                  another love song
#
#                        id  danceability  energy  key  loudness  mode  \
# 0  77v5yDwMLiJlIsHNJQxXrY         0.484   0.995    7    -5.300     1
# 1  4xfAVJL8R7mVYbDk8a9xOY         0.576   0.367    1   -14.785     1
# 2  5x46pk7OZUv1WWiP6iEdMy         0.854   0.356    6    -8.780     1
# 3  6WfjV745TiUcD8KdUKp241         0.384   0.817    1    -9.079     1
# 4  5HjEC3NlSzKsVKmqnhXrum         0.376   0.756    9    -4.930     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1020      0.000248          0.001130    0.3810   0.0771  109.556
# 1       0.0300      0.432000          0.000002    0.1240   0.7700  108.446
# 2       0.0609      0.863000          0.000675    0.1310   0.8450  113.283
# 3       0.0661      0.267000          0.001910    0.0756   0.6850  128.490
# 4       0.0657      0.136000          0.015500    0.3760   0.4540  146.114
#
#              type                                   uri  \
# 0  audio_features  spotify:track:77v5yDwMLiJlIsHNJQxXrY
# 1  audio_features  spotify:track:4xfAVJL8R7mVYbDk8a9xOY
# 2  audio_features  spotify:track:5x46pk7OZUv1WWiP6iEdMy
# 3  audio_features  spotify:track:6WfjV745TiUcD8KdUKp241
# 4  audio_features  spotify:track:5HjEC3NlSzKsVKmqnhXrum
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/77v5yDwMLiJl...
# 1  https://api.spotify.com/v1/tracks/4xfAVJL8R7mV...
# 2  https://api.spotify.com/v1/tracks/5x46pk7OZUv1...
# 3  https://api.spotify.com/v1/tracks/6WfjV745TiUc...
# 4  https://api.spotify.com/v1/tracks/5HjEC3NlSzKs...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/77v5...       126907
# 1  https://api.spotify.com/v1/audio-analysis/4xfA...       129333
# 2  https://api.spotify.com/v1/audio-analysis/5x46...       138600
# 3  https://api.spotify.com/v1/audio-analysis/6Wfj...       285760
# 4  https://api.spotify.com/v1/audio-analysis/5HjE...       195558
#
#    time_signature
# 0               4
# 1               4
# 2               4
# 3               4
# 4               4

# %%
hot_songs_audio.to_csv('hot_songs_audio_features.csv',sep=';', index=False)

# %%
not_hot_songs_audio.to_csv('not_hot_songs_audio_features.csv',sep=';', index=False)
